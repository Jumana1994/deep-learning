# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# data.drop(["chlorides","free sulfur dioxide","total sulfur dioxide","pH","density","sulphates"],axis=1)

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
# data=pd.DataFrame(data["quality"],colomns=[1,2,3,4,11])

# %%
data['fixed acidity']=scale.fit_transform(data[['fixed acidity']])
data['volatile acidity']=scale.fit_transform(data[['volatile acidity']])
data['citric acid']=scale.fit_transform(data[['citric acid']])
data['residual sugar']=scale.fit_transform(data[['residual sugar']])
data['alcohol']=scale.fit_transform(data[['alcohol']])
data['chlorides']=scale.fit_transform(data[['chlorides']])
data['free sulfur dioxide']=scale.fit_transform(data[['free sulfur dioxide']])
data['total sulfur dioxide']=scale.fit_transform(data[['total sulfur dioxide']])
data['sulphates']=scale.fit_transform(data[['sulphates']])
data['pH']=scale.fit_transform(data[['pH']])
data['density']=scale.fit_transform(data[['density']])
data['quality']=scale.fit_transform(data[['quality']])

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
x=data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'alcohol', 'quality','chlorides', 'free sulfur dioxide','total sulfur dioxide', 'density',
       'pH', 'sulphates']]

# %%
k_range=range(1,11)
from sklearn.cluster import KMeans
result=[]
for i in k_range:
    model=KMeans(n_clusters=i)
    model.fit_predict(x)
    result.append(model.inertia_)

# %%
result
# Out:
# [359.0599926019826,
#  276.91363053353143,
#  241.1969984262348,
#  215.69495230073386,
#  197.59543696113911,
#  188.56745733070179,
#  177.58893519131715,
#  170.28276701761362,
#  163.65862832764066,
#  157.60585041197646]

# %%
plt.plot(k_range,result,marker='o',color='b')
plt.xlabel("clusters")
plt.ylabel("values")
# Out:
# Text(0, 0.5, 'values')

# %%
model=KMeans(n_clusters=3)
y_pred=model.fit_predict(x)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
data['group']=y_pred

# %%
group1=data[data['group']==0]
group2=data[data['group']==1]
group3=data[data['group']==2]

# %%
group3
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 16         0.345133          0.109589         0.56        0.061644   0.133556
# 19         0.292035          0.136986         0.51        0.061644   0.549249
# 20         0.380531          0.068493         0.48        0.061644   0.108514
# 47         0.362832          0.116438         0.52        0.047945   0.168614
# ...             ...               ...          ...             ...        ...
# 1528       0.292035          0.116438         0.49        0.089041   0.140234
# 1543       0.575221          0.219178         0.42        0.089041   0.086811
# 1548       0.584071          0.191781         0.50        0.075342   0.145242
# 1574       0.088496          0.130137         0.78        0.890411   0.103506
# 1576       0.300885          0.123288         0.63        0.047945   0.115192
#
# ...
